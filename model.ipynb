# %%
from tensorflow import keras

# %%
model = keras.models.load_model('parrot_model.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# image_input (InputLayer)        [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 417, 417, 3)  0           image_input[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 208, 208, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (SyncBatchNormalizatio (None, 208, 208, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 208, 208, 32) 0           conv1_bn[0][0]
# ...

# %%
model.outputs
# Out:
# [<tf.Tensor 'predict_conv_1/BiasAdd:0' shape=(None, 13, 13, 30) dtype=float32>,
#  <tf.Tensor 'predict_conv_2/BiasAdd:0' shape=(None, 26, 26, 30) dtype=float32>,
#  <tf.Tensor 'predict_conv_3/BiasAdd:0' shape=(None, 52, 52, 30) dtype=float32>]
